# %% [markdown]
# # File Formats Appendix
#
# We also need to be able to format files in specific structures. Hence, one more task:
#
# 4. Take your recursive parsing algorithm from yesterday. Write a function that takes the resulting parsed object and outputs the same HTML that generated it. (It can be semantically the same; it does not have to be byte-for-byte the same, as long as it would parse again with zero information loss.)
#
#  <details>
#  <summary>Click for hint</summary>
#
#  > Indentation can be implemented the same as the flatten dictionary key-chaining.
#  </details>
